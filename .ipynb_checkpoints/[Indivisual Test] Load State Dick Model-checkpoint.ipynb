# %%
import os
import os.path as osp
import cv2
import copy
import random
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score,accuracy_score, confusion_matrix, classification_report
import seaborn as sns
from tqdm import tqdm
from collections import Counter

from torch.utils.data import Dataset,DataLoader
from torchvision import transforms as T
import torch
import torch.nn as nn

from models.Network import Face_Detection_Model
from dataloader.dataloader import Facedata_Loader

device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
    
## Set seeds
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
#     torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

# seed = 7023001
seed = 1
seed_everything(seed)
# Out:
# Using device: cuda:1

# %%
class FaceData(Dataset):
    def __init__(self,data_paths,transform_apply=True) :
        self.data_paths = data_paths
        self.transform_apply = transform_apply
        
        normalize = T.Normalize(mean=[0.485, 0.456, 0.406],std = [0.229, 0.224, 0.225])
        self.transforms = T.Compose([
            T.ToTensor(),
            normalize
        ])
        
    def __getitem__(self, index):
        rgb_path = self.data_paths[index][0]
        cloud_path = self.data_paths[index][1]
        
        # crop setting
        crop_width = 90
        crop_height = 150
        mid_x, mid_y = 90, 90
        offset_x, offset_y = crop_width//2, crop_height//2
        
        # RGB open and crop 
        data = cv2.imread(rgb_path)
        data = cv2.cvtColor(data, cv2.COLOR_BGR2RGB)
        data = cv2.resize(data, (180,180), interpolation=cv2.INTER_CUBIC)
        data = data[mid_y-offset_y:mid_y+offset_y, mid_x-offset_x:mid_x+offset_x]     
        
        print('?',data.shape)
        if (self.transform_apply) and (self.transforms is not None) :
            data = self.transforms(data)
            
        # Point Cloud(192, 256, 3) open and crop 
        cloud_data = np.load(cloud_path)
        cloud_data = cv2.resize(cloud_data, (180,180), interpolation=cv2.INTER_CUBIC)
        cloud_data += 5
        cloud_data = cloud_data[mid_y-offset_y:mid_y+offset_y, mid_x-offset_x:mid_x+offset_x]
        
        ###### [!!!]  If A data is not scaled, it causes low performance.
        shift_value = 0
        xcoor = np.array(cloud_data[:, :, 0] + shift_value)
        ycoor = np.array(cloud_data[:, :, 1] + shift_value)
        zcoor = np.array(cloud_data[:, :, 2] + shift_value)
        depth = np.array(cloud_data[:, :, 3] + shift_value)
        
        xcoor = (xcoor-xcoor.mean())/xcoor.std()
        ycoor = (ycoor-ycoor.mean())/ycoor.std()
        zcoor = (zcoor-zcoor.mean())/zcoor.std()
        depth = (depth-depth.mean())/depth.std()     
        
        scaled_cloud_depth = np.concatenate([xcoor[np.newaxis,:],ycoor[np.newaxis,:],zcoor[np.newaxis,:],depth[np.newaxis,:]])
  
        # label - { 0 : real , 1 : mask }
        if 'bonafide' in rgb_path :
            label = 0
        elif 'attack_mask' in rgb_path :
            label = 1
        elif 'attack_replay' in rgb_path :
            label = 1
        elif 'attack_paper' in rgb_path :
            label = 1
        return data,cloud_data,scaled_cloud_depth, label
    
    def __len__(self):
        return len(self.data_paths)

# %%
person_number = [i for i in range(13,16)]
person_number
# Out:
# [13, 14, 15]

# %%
data_path = "/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS"
npy_path = '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files'

experiment_type = "p"

person_number = [i for i in range(13,14)]
traindata_portion = 0

train_img_paths, test_img_paths = [],[]
for i in person_number :
    img_path = osp.join(data_path,str(i),'bonafide')
    files = os.listdir(img_path)
    files = [j for j in files if (j.split('.')[-1]=='jpg') and (j.split('_')[0]=='rgb')]
    random.shuffle(files)
    
    bonafide_files = [osp.join(data_path,str(i),'bonafide',j) for j in files]
    paper_files= [osp.join(data_path,str(i),'attack_paper',j) for j in files]
    replay_files= [osp.join(data_path,str(i),'attack_replay',j) for j in files]
    mask_files= [osp.join(data_path,str(i),'attack_mask',j) for j in files]

    bonafide_cloud_files = [osp.join(npy_path, 'real_cloud_data',j.split('/')[-3], 
                            (('pc_'+j.split('/')[-1].split('_')[-1]).split('.')[0]+'.npy')) for j in bonafide_files]
    paper_cloud_files = [osp.join(npy_path, 'paper_cloud_data',j.split('/')[-3], 
                            (('pc_'+j.split('/')[-1].split('_')[-1]).split('.')[0]+'.npy')) for j in paper_files]
    replay_cloud_files = [osp.join(npy_path, 'replay_cloud_data',j.split('/')[-3], 
                            (('pc_'+j.split('/')[-1].split('_')[-1]).split('.')[0]+'.npy')) for j in replay_files]
    mask_cloud_files = [osp.join(npy_path, 'mask_cloud_data',j.split('/')[-3], 
                            (('pc_'+j.split('/')[-1].split('_')[-1]).split('.')[0]+'.npy')) for j in mask_files]

    # bonafide
    train_img_paths += list(zip(bonafide_files,bonafide_cloud_files))[:int(len(bonafide_files)*traindata_portion)]
    test_img_paths += list(zip(bonafide_files,bonafide_cloud_files))[int(len(bonafide_files)*traindata_portion):]
    
    # PAs
    if "r" in experiment_type:
        train_img_paths += list(zip(replay_files,replay_cloud_files))[:int(len(replay_files)*traindata_portion)]
        test_img_paths += list(zip(replay_files,replay_cloud_files))[int(len(replay_files)*traindata_portion):]
    if "p" in experiment_type:
        train_img_paths += list(zip(paper_files,paper_cloud_files))[:int(len(paper_files)*traindata_portion)]
        test_img_paths += list(zip(paper_files,paper_cloud_files))[int(len(paper_files)*traindata_portion):]
    if "m" in experiment_type:
        train_img_paths += list(zip(mask_files,mask_cloud_files))[:int(len(mask_files)*traindata_portion)]
        test_img_paths += list(zip(mask_files,mask_cloud_files))[int(len(mask_files)*traindata_portion):]
     
test_img_paths = sorted(test_img_paths)
test_img_paths
# Out:
# [('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_1.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_1.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_10.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_10.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_11.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_11.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_12.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_12.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_13.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_13.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_14.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_14.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_15.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_15.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_16.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_16.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_17.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_17.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_18.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_18.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_19.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_19.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_2.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_2.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_20.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_20.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_3.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_3.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_4.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_4.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_5.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_5.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_6.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_6.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_7.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_7.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_8.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_8.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/attack_paper/rgb_9.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/paper_cloud_data/13/pc_9.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_1.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_1.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_10.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_10.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_11.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_11.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_12.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_12.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_13.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_13.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_14.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_14.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_15.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_15.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_16.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_16.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_17.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_17.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_18.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_18.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_19.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_19.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_2.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_2.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_20.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_20.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_3.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_3.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_4.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_4.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_5.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_5.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_6.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_6.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_7.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_7.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_8.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_8.npy'),
#  ('/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/13/bonafide/rgb_9.jpg',
#   '/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/real_cloud_data/13/pc_9.npy')]

# %%
batch_size = 1
num_workers = 1

test_dataset = FaceData(test_img_paths,transform_apply=False)
test_loader = DataLoader(test_dataset, batch_size = batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)

len(test_dataset)
# Out:
# 40

# %%
# model_path = "/mnt/nas3/yrkim/liveness_lidar_project/GC_project/bc_output/checkpoint/0721_data15_82_rgb_p/epoch_18_model.pth"

# model = Face_Detection_Model(3).to(device)
# model.load_state_dict(torch.load(model_path), strict=False)
# model.eval()

# %%
model = Face_Detection_Model(3)
ckpt = torch.load(model_path)
model.load_state_dict(ckpt['model_state_dict'])
model.to(device)
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
def noisy(noise_typ,image):
    if noise_typ == "gauss":
        row,col,ch= image.shape
        mean = 0
        
        var = 0.1
        
        sigma = var**0.5
        gauss = np.random.normal(mean,sigma,(row,col,ch))
        gauss = gauss.reshape(row,col,ch)
        noisy = image + gauss
        return noisy
    elif noise_typ == "s&p":
        row,col,ch = image.shape
        s_vs_p = 0.5
        amount = 0.004
        out = np.copy(image)
        # Salt mode
        num_salt = np.ceil(amount * image.size * s_vs_p)
        coords = [np.random.randint(0, i - 1, int(num_salt))
              for i in image.shape]
#         print(image.shape,num_salt)
#         print('??',np.random.randint(0, 366 - 1, int(num_salt)),image.shape)
        out[tuple(coords)] = 1

        # Pepper mode
        num_pepper = np.ceil(amount* image.size * (1. - s_vs_p))
        coords = [np.random.randint(0, i - 1, int(num_pepper))
              for i in image.shape]
        out[tuple(coords)] = 0
        return out
    elif noise_typ == "poisson":
        vals = len(np.unique(image))
        vals = 2 ** np.ceil(np.log2(vals))
        noisy = np.random.poisson(image * vals) / float(vals)
        return noisy
    elif noise_typ =="speckle":
        row,col,ch = image.shape
        gauss = np.random.randn(row,col,ch)
        gauss = gauss.reshape(row,col,ch)        
        noisy = image + image * gauss
        return noisy

# %%
train_performs, test_performs = {'ACC':[],'F1':[]},{'ACC':[],'F1':[]}
best_test_f1 = 0
start_epoch = 0
epochs = 100
sigmoid = nn.Sigmoid()
loss_fn = nn.BCEWithLogitsLoss()

start_time = datetime.now()    
test_loss = []
test_probs, test_labels = [],[]
    
test_bar = tqdm(enumerate(test_loader))
for step, batch in test_bar :  
    rgb,cloud,label = batch[0].float().to(device),batch[2].float().to(device),batch[3].to(device)
#         cloud = cloud.permute(0,3,1,2)
#         features = torch.concat([rgb,cloud],dim=1)

    features = copy.deepcopy(rgb)
    features = noisy('s&p',np.array(rgb[0].cpu(),dtype=np.uint8))
    plt.imshow(features)
    plt.show()
    features = torch.tensor(features,dtype=torch.float32).unsqueeze(0).permute(0,3,1,2).to(device)
    features = test_dataset.transforms(np.array(features[0].permute(1,2,0).cpu(),dtype=np.uint8))
    features = features.unsqueeze(0).to(device)
    
    logits,_ = model(features)
    logits = logits[:,0]
    loss = loss_fn(logits,label.float())

    probs = sigmoid(logits)
    
#     plt.imshow(np.array(features[0].permute(1,2,0).cpu(),dtype=np.uint8))
#     plt.show()
    print(f"probs: {probs.cpu().detach().tolist()}")
#     print(f"label: {label.cpu().detach().tolist()}")
    print('label : {} , pred : {}'.format(label.cpu().detach().tolist(),np.round(probs.cpu().detach().numpy())))
    
    test_probs += probs.cpu().detach().tolist()
    test_labels += label.cpu().detach().tolist()
    
#     break

#     test_bar.set_description("[Test] Epoch[{}/{}][{}/{}] Loss:{} Loss(mean):{}".format(epoch+1,epochs,step+1,len(test_loader),
#                                                 round(loss.item(),5),round(np.array(test_loss).mean(),5)
#                                                          ))
# test_acc = accuracy_score(np.array(test_labels), np.round(test_probs))
# test_f1 = f1_score(np.array(test_labels), np.round(test_probs), average='macro')
# print('Test Accuracy :',test_acc)
# print('Test F1-score :',test_f1)
# test_performs['ACC'].append(test_acc)
# test_performs['F1'].append(test_f1)
# print('  > Counter(test_labels) :',Counter(test_labels))
# print('  > Counter(test_probs) :',Counter(np.round(test_probs)))
# cf = confusion_matrix(np.array(test_labels), np.round(test_probs))
# cf = pd.DataFrame(cf)
# cf.columns = ['Predicted:0','Predicted:1']
# cf.index = ['Label:0','Label:1']    
# print(' --- [Test] Confustion_Matrix & Classification_Report --- ')
# display(cf)
# report = classification_report(np.array(test_labels), np.round(test_probs))
# print(report)

# if best_test_f1 < test_f1 :
#     print(' @@ New Best test_f1 !! @@ ')
#     best_test_f1 = test_f1 
#     print(' @@ Best Test Accuracy :',np.array(test_performs['ACC']).max())
#     print(' @@ Best Test F1-Score :',best_test_f1)
          
        
# print(' @@ THE END @@ ')
# print('  > Train Best Accuracy :',np.array(train_performs['ACC']).max())
# print('  > Train Best F1-Score :',np.array(train_performs['F1']).max())
# print('  > Test Best Accuracy :',np.array(test_performs['ACC']).max())
# print('  > Test Best F1-Score :',np.array(test_performs['F1']).max())
# print()
# print('Train time : {}'.format(datetime.now() - start_time))
# Out:
# 0it [00:00, ?it/s]
# ? (150, 90, 3)
# ? (150, 90, 3)
# ? (150, 90, 3)
# 1it [00:00,  2.83it/s]
# ? (150, 90, 3)
# probs: [0.9988629817962646]
# label : [1] , pred : [1.]
# 2it [00:00,  4.54it/s]
# ? (150, 90, 3)
# probs: [0.9994702935218811]
# label : [1] , pred : [1.]
# 3it [00:00,  6.02it/s]
# ? (150, 90, 3)
# probs: [0.9954894185066223]
# label : [1] , pred : [1.]
# 4it [00:00,  7.06it/s]
# ?
#  (150, 90, 3)probs: [0.9953483939170837]
# label : [1] , pred : [1.]
# 5it [00:00,  7.81it/s]
# ? (150, 90, 3)
# probs: [0.995151162147522]
# label : [1] , pred : [1.]
# 6it [00:00,  8.12it/s]
# ?
#  (150, 90, 3)probs: [0.9953311085700989]
# label : [1] , pred : [1.]
# 7it [00:01,  8.25it/s]
# ? (150, 90, 3)
# probs: [0.995405912399292]
# label : [1] , pred : [1.]
# 8it [00:01,  8.18it/s]
# ? (150, 90, 3)
# probs: [0.9954249262809753]
# label : [1] , pred : [1.]
# 9it [00:01,  8.56it/s]
# ? (150, 90, 3)
# probs: [0.9951050281524658]
# label : [1] , pred : [1.]
# 10it [00:01,  8.93it/s]
# ? (150, 90, 3)
# probs: [0.9953232407569885]
# label : [1] , pred : [1.]
# 11it [00:01,  9.20it/s]
# ? (150, 90, 3)
# probs: [0.9952152967453003]
# label : [1] , pred : [1.]
# 12it [00:01,  8.57it/s]
# ? (150, 90, 3)
# probs: [0.9988651275634766]
# label : [1] , pred : [1.]
# 13it [00:01,  8.83it/s]
# ? (150, 90, 3)
# probs: [0.9947708249092102]
# label : [1] , pred : [1.]
# 14it [00:01,  8.57it/s]
# ? (150, 90, 3)
# probs: [0.9995465874671936]
# label : [1] , pred : [1.]
# 15it [00:01,  8.40it/s]
# ? (150, 90, 3)
# probs: [0.9999306201934814]
# label : [1] , pred : [1.]
# 16it [00:02,  7.92it/s]
# ? (150, 90, 3)
# probs: [0.9995194673538208]
# label : [1] , pred : [1.]
# 17it [00:02,  7.92it/s]
# ? (150, 90, 3)
# probs: [0.999678373336792]
# label : [1] , pred : [1.]
# 18it [00:02,  7.66it/s]
# ?
#  (150, 90, 3)probs: [0.9962347149848938]
# label : [1] , pred : [1.]
# 19it [00:02,  7.73it/s]
# ? (150, 90, 3)
# probs: [0.998766303062439]
# label : [1] , pred : [1.]
# 20it [00:02,  7.56it/s]
# ?
# (150, 90, 3)probs: [0.9998084902763367]
# label : [1] , pred : [1.]
# 21it [00:02,  7.20it/s]
# ? (150, 90, 3)
# probs: [6.226649566087872e-05]
# label : [0] , pred : [0.]
# 22it [00:02,  7.46it/s]
# ?probs: [0.0001598764065420255]
# label : [0] , pred : [0.]
#  (150, 90, 3)
# 23it [00:03,  5.78it/s]
# ? (150, 90, 3)
# probs: [0.000387211941415444]
# label : [0] , pred : [0.]
# 24it [00:03,  6.19it/s]
# ? (150, 90, 3)
# probs: [0.000608649046625942]
# label : [0] , pred : [0.]
# 25it [00:03,  6.61it/s]
# ?
#  (150, 90, 3)probs: [0.0007262950530275702]
# label : [0] , pred : [0.]
# 26it [00:03,  6.90it/s]
# ? (150, 90, 3)
# probs: [0.0011567655019462109]
# label : [0] , pred : [0.]
# 27it [00:03,  7.37it/s]
# ?
# (150, 90, 3)probs: [0.00019518908811733127]
# label : [0] , pred : [0.]
# 28it [00:03,  7.54it/s]
# ? (150, 90, 3)
# probs: [0.0005482817068696022]
# label : [0] , pred : [0.]
# 29it [00:03,  7.65it/s]
# ? (150, 90, 3)
# probs: [0.0003538962628226727]
# label : [0] , pred : [0.]
# 30it [00:04,  7.86it/s]
# ? (150, 90, 3)
# probs: [0.0004959352663718164]
# label : [0] , pred : [0.]
# 31it [00:04,  7.91it/s]
# ?
#  (150, 90, 3)probs: [0.0013715422246605158]
# label : [0] , pred : [0.]
# 32it [00:04,  7.98it/s]
# ?
#  (150, 90, 3)probs: [5.2931074606021866e-05]
# label : [0] , pred : [0.]
# 33it [00:04,  7.93it/s]
# ?
# (150, 90, 3)probs: [0.00037152302684262395]
# label : [0] , pred : [0.]
# 34it [00:04,  7.90it/s]
# ? (150, 90, 3)
# probs: [0.0028379694558680058]
# label : [0] , pred : [0.]
# 35it [00:04,  7.98it/s]
# ? (150, 90, 3)
# probs: [2.139879870810546e-05]
# label : [0] , pred : [0.]
# 36it [00:04,  8.02it/s]
# ? (150, 90, 3)
# probs: [1.4765994819754269e-05]
# label : [0] , pred : [0.]
# 37it [00:04,  7.60it/s]
# ? (150, 90, 3)
# probs: [0.0010747346095740795]
# label : [0] , pred : [0.]
# 38it [00:05,  7.79it/s]
# probs: [5.667476216331124e-06]
# label : [0] , pred : [0.]
# 39it [00:05,  8.07it/s]
# probs: [0.00020034998306073248]
# label : [0] , pred : [0.]
# 40it [00:05,  8.23it/s]
# probs: [0.004495406057685614]
# label : [0] , pred : [0.]
# 40it [00:05,  7.43it/s]

# %%
features.shape
# Out:
# torch.Size([1, 3, 150, 90])

# %%
t = np.array(rgb[0].cpu(),dtype=np.uint8)
plt.imshow(t)

# %%
t2 = noisy('gauss',t)
# print(t2)
plt.imshow(t2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
f1_score(np.array(test_labels), np.round(test_probs), average='macro')
# Out:
# 0.7395833333333333

# %%
test_cf = confusion_matrix(np.array(test_labels), np.round(test_probs))
test_cf = pd.DataFrame(test_cf)
test_cf.columns = ['Predicted:0','Predicted:1']
test_cf.index = ['Label:0','Label:1']    
test_cf
# Out:
#          Predicted:0  Predicted:1
# Label:0           19            1
# Label:1            9           11

# %%
test_dataset.transforms
# Out:
# Compose(
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# )

# %%
t = test_dataset.transforms(np.array(features[0].permute(1,2,0).cpu(),dtype=np.uint8))
t = t.unsqueeze(0)

# %%
t.shape
# Out:
# torch.Size([1, 3, 150, 90])

# %%
features.shape
# Out:
# torch.Size([1, 3, 150, 90])

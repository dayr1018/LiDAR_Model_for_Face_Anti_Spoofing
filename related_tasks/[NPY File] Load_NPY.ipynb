# %%
import numpy as np
import cv2
import seaborn

# %%
# cloud_path = "/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/1. Indoor/real_cloud_data/2/pc_1.npy"
# cloud_path = "/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/1. Indoor/paper_cloud_data/2/pc_1.npy"
# cloud_path = "/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/1. Indoor/replay_cloud_data/2/pc_1.npy"
# cloud_path = "/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/1. Indoor/mask_cloud_data/2/pc_1.npy"

# cloud_path = "/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/2. Outdoor/real_cloud_data/2/pc_1.npy"
# cloud_path = "/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/2. Outdoor/paper_cloud_data/2/pc_1.npy"
# cloud_path = "/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/2. Outdoor/replay_cloud_data/2/pc_1.npy"
cloud_path = "/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/NPY_Files/2. Outdoor/mask_cloud_data/2/pc_1.npy"




cloud_data = np.load(cloud_path)
cloud_data = cv2.resize(cloud_data, (180,180), interpolation=cv2.INTER_CUBIC)
cloud_data += 5

# Point Cloud and Depth Scaling
shift_value = 0
xcoor = np.array(cloud_data[:, :, 0] + shift_value)
ycoor = np.array(cloud_data[:, :, 1] + shift_value)
zcoor = np.array(cloud_data[:, :, 2] + shift_value)

xcoor = (xcoor-xcoor.mean())/xcoor.std()
ycoor = (ycoor-ycoor.mean())/ycoor.std()
zcoor = (zcoor-zcoor.mean())/zcoor.std()

# xcoor = (xcoor-xcoor.min())/(xcoor.max()-xcoor.min())
# ycoor = (ycoor-ycoor.min())/(ycoor.max()-ycoor.min())
# zcoor = (zcoor-zcoor.min())/(zcoor.max()-zcoor.min())

# %%
seaborn.heatmap(xcoor)
# Out:
# <AxesSubplot:>

# %%
seaborn.heatmap(ycoor)
# Out:
# <AxesSubplot:>

# %%
seaborn.heatmap(zcoor)
# Out:
# <AxesSubplot:>

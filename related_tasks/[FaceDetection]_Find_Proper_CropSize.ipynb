# %%
from PIL import Image
import torch
from torchvision import transforms

# %%
bonafide = []
mask = []
replay = []
paper = []

for i in range(1,16):
    bonafide.append(f"/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/{i}/bonafide/rgb_13.jpg")
    mask.append(f"/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/{i}/attack_mask/rgb_3.jpg")
    replay.append(f"/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/{i}/attack_replay/rgb_3.jpg")
    paper.append(f"/mnt/nas3/yrkim/liveness_lidar_project/GC_project/LDFAS/{i}/attack_paper/rgb_3.jpg")

# %%
subject=1

image = Image.open(bonafide[subject])
# image = Image.open(mask[subject])
# image = Image.open(replay[subject])
# image = Image.open(paper[subject])


transform = transforms.Compose([
    transforms.Resize((128,128)),
])

bonfide_new = transform(image)
print(bonfide_new.size)
bonfide_new
# Out:
# (128, 128)
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F9EAEE1C898>

# %%
image = Image.open(bonafide[subject])
# image = Image.open(mask[subject])
# image = Image.open(replay[subject])
# image = Image.open(paper[subject])


transform1 = transforms.Compose([
    transforms.Resize((128,128)),
    transforms.CenterCrop((120,80))
])

bonfide_new = transform1(image)
print(bonfide_new.size)
bonfide_new
# Out:
# (80, 120)
# <PIL.Image.Image image mode=RGB size=80x120 at 0x7F9EAE2D6A58>

# %%
image = Image.open(bonafide[subject])
# image = Image.open(mask[subject])
# image = Image.open(replay[subject])
# image = Image.open(paper[subject])


transform2 = transforms.Compose([
    transforms.Resize((128,128)),
    transforms.CenterCrop((110,75))
])

bonfide_new = transform2(image)
print(bonfide_new.size)
bonfide_new
# Out:
# (75, 110)
# <PIL.Image.Image image mode=RGB size=75x110 at 0x7F9EAE2D6828>
